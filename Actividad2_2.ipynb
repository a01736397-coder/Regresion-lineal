# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
info_forvia_processed = pd.read_csv("projectos_forvia.csv")

# %%
info_forvia_processed.isnull().sum()
# Out:
# Number                    1
# Active                    1
# Project Name              1
# Project Type              1
# Geographical scope        1
# Project manager           1
# State                     1
# Percent complete          1
# Project size              1
# Project organization      1
# Planned Go Live date      1
# Project target phase    174
# Actual Go Live date     198
# Actual end date         246
# BG                        1
# Closed                  245
# Domain                    1
# Domain Path               1
# Last WAR                 14
# Project Health           14
# Project type              1
# Recurrent activity        1
# Planned start date        0
# Actual start date        19
# On-hold                   1
# dtype: int64

# %%
info_forvia_processed[["Number", "Active", "Project Name"]] = info_forvia_processed[["Number", "Active", "Project Name"]].fillna("NO DEFINE")
info_forvia_processed.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              1
# Geographical scope        1
# Project manager           1
# State                     1
# Percent complete          1
# Project size              1
# Project organization      1
# Planned Go Live date      1
# Project target phase    174
# Actual Go Live date     198
# Actual end date         246
# BG                        1
# Closed                  245
# Domain                    1
# Domain Path               1
# Last WAR                 14
# Project Health           14
# Project type              1
# Recurrent activity        1
# Planned start date        0
# Actual start date        19
# On-hold                   1
# dtype: int64

# %%
info_forvia_processed[["Project Type", "Geographical scope", "Project manager", "State"]] = info_forvia_processed[["Project Type", "Geographical scope", "Project manager", "State"]].fillna("NO DEFINE")
info_forvia_processed.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          1
# Project size              1
# Project organization      1
# Planned Go Live date      1
# Project target phase    174
# Actual Go Live date     198
# Actual end date         246
# BG                        1
# Closed                  245
# Domain                    1
# Domain Path               1
# Last WAR                 14
# Project Health           14
# Project type              1
# Recurrent activity        1
# Planned start date        0
# Actual start date        19
# On-hold                   1
# dtype: int64

# %%
info_forvia_processed[["Percent complete"]] = info_forvia_processed[["Percent complete"]].fillna("0")
info_forvia_processed.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          0
# Project size              1
# Project organization      1
# Planned Go Live date      1
# Project target phase    174
# Actual Go Live date     198
# Actual end date         246
# BG                        1
# Closed                  245
# Domain                    1
# Domain Path               1
# Last WAR                 14
# Project Health           14
# Project type              1
# Recurrent activity        1
# Planned start date        0
# Actual start date        19
# On-hold                   1
# dtype: int64

# %%
info_forvia_processed[["Project size", "Project organization", "Planned Go Live date"]] = info_forvia_processed[["Project size", "Project organization", "Planned Go Live date"]].fillna("NO DEFINE")
info_forvia_processed.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          0
# Project size              0
# Project organization      0
# Planned Go Live date      0
# Project target phase    174
# Actual Go Live date     198
# Actual end date         246
# BG                        1
# Closed                  245
# Domain                    1
# Domain Path               1
# Last WAR                 14
# Project Health           14
# Project type              1
# Recurrent activity        1
# Planned start date        0
# Actual start date        19
# On-hold                   1
# dtype: int64

# %%
info_forvia_processed[["Domain"]] = info_forvia_processed[["Domain"]].fillna("Global")
info_forvia_processed.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          0
# Project size              0
# Project organization      0
# Planned Go Live date      0
# Project target phase    174
# Actual Go Live date     198
# Actual end date         246
# BG                        1
# Closed                  245
# Domain                    0
# Domain Path               1
# Last WAR                 14
# Project Health           14
# Project type              1
# Recurrent activity        1
# Planned start date        0
# Actual start date        19
# On-hold                   1
# dtype: int64

# %%
info_forvia_processed[["BG"]] = info_forvia_processed[["BG"]].fillna("NO DEFINE")
info_forvia_processed.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          0
# Project size              0
# Project organization      0
# Planned Go Live date      0
# Project target phase    174
# Actual Go Live date     198
# Actual end date         246
# BG                        0
# Closed                  245
# Domain                    0
# Domain Path               1
# Last WAR                 14
# Project Health           14
# Project type              1
# Recurrent activity        1
# Planned start date        0
# Actual start date        19
# On-hold                   1
# dtype: int64

# %%
info_forvia_processed[["Domain Path"]] = info_forvia_processed[["Domain Path"]].fillna("/")
info_forvia_processed.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          0
# Project size              0
# Project organization      0
# Planned Go Live date      0
# Project target phase    174
# Actual Go Live date     198
# Actual end date         246
# BG                        0
# Closed                  245
# Domain                    0
# Domain Path               0
# Last WAR                 14
# Project Health           14
# Project type              1
# Recurrent activity        1
# Planned start date        0
# Actual start date        19
# On-hold                   1
# dtype: int64

# %%
info_forvia_processed[["Project type"]] = info_forvia_processed[["Project type"]].fillna("REGULAR")
info_forvia_processed.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          0
# Project size              0
# Project organization      0
# Planned Go Live date      0
# Project target phase    174
# Actual Go Live date     198
# Actual end date         246
# BG                        0
# Closed                  245
# Domain                    0
# Domain Path               0
# Last WAR                 14
# Project Health           14
# Project type              0
# Recurrent activity        1
# Planned start date        0
# Actual start date        19
# On-hold                   1
# dtype: int64

# %%
info_forvia_processed[["Recurrent activity"]] = info_forvia_processed[["Recurrent activity"]].fillna("FALSO")
info_forvia_processed.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          0
# Project size              0
# Project organization      0
# Planned Go Live date      0
# Project target phase    174
# Actual Go Live date     198
# Actual end date         246
# BG                        0
# Closed                  245
# Domain                    0
# Domain Path               0
# Last WAR                 14
# Project Health           14
# Project type              0
# Recurrent activity        0
# Planned start date        0
# Actual start date        19
# On-hold                   1
# dtype: int64

# %%
info_forvia_processed[["On-hold"]] = info_forvia_processed[["On-hold"]].fillna("NO DEFINE")
info_forvia_processed.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          0
# Project size              0
# Project organization      0
# Planned Go Live date      0
# Project target phase    174
# Actual Go Live date     198
# Actual end date         246
# BG                        0
# Closed                  245
# Domain                    0
# Domain Path               0
# Last WAR                 14
# Project Health           14
# Project type              0
# Recurrent activity        0
# Planned start date        0
# Actual start date        19
# On-hold                   0
# dtype: int64

# %%
info_forvia_processed=info_forvia_processed.drop(['Actual end date', 'Closed'],axis=1)
info_forvia_processed.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          0
# Project size              0
# Project organization      0
# Planned Go Live date      0
# Project target phase    174
# Actual Go Live date     198
# BG                        0
# Domain                    0
# Domain Path               0
# Last WAR                 14
# Project Health           14
# Project type              0
# Recurrent activity        0
# Planned start date        0
# Actual start date        19
# On-hold                   0
# dtype: int64

# %%
info_forvia_processed[["Project target phase", "Actual Go Live date", "Last WAR", "Project Health", "Actual start date"]] = info_forvia_processed[["Project target phase", "Actual Go Live date", "Last WAR", "Project Health", "Actual start date"]].fillna("NO DEFINE")
info_forvia_processed.isnull().sum()
# Out:
# Number                  0
# Active                  0
# Project Name            0
# Project Type            0
# Geographical scope      0
# Project manager         0
# State                   0
# Percent complete        0
# Project size            0
# Project organization    0
# Planned Go Live date    0
# Project target phase    0
# Actual Go Live date     0
# BG                      0
# Domain                  0
# Domain Path             0
# Last WAR                0
# Project Health          0
# Project type            0
# Recurrent activity      0
# Planned start date      0
# Actual start date       0
# On-hold                 0
# dtype: int64

# %%
lista = ['Project Type','Geographical scope','Project manager','State','Project size','Project organization','BG','Project Health','On-hold']

# %%
n=0
datos_numericos = info_forvia_processed.copy()
for col in lista:
    Tabla_freq = info_forvia_processed[col].value_counts()
    mapeo = {cat: i+1 for i, cat in enumerate(Tabla_freq.index.unique())}
    info_forvia_processed[col] = info_forvia_processed[col].map(mapeo)

Tabla_final_num =info_forvia_processed[lista]
Tabla_final_num["Percent complete"] = info_forvia_processed["Percent complete"]
Tabla_final_num.head(15)
# Out:
# C:\Users\maryk\AppData\Local\Temp\ipykernel_27988\3166740037.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tabla_final_num["Percent complete"] = info_forvia_processed["Percent complete"]
#     Project Type  Geographical scope  Project manager  State  Project size  \
# 0              1                  63                2      1             3
# 1              1                  62               15      1             2
# 2              1                  51               20      1             1
# 3              1                  51               15      1             3
# 4              1                  61                2      1             1
# 5              4                  57               50      1             2
# ...

# %%
# Calcular la matriz de correlación
corr = Tabla_final_num.corr()
# Mostrar la matriz
print(corr)
# Out:
#                       Project Type  Geographical scope  Project manager  \
# Project Type              1.000000            0.058818         0.304068
# Geographical scope        0.058818            1.000000         0.099880
# Project manager           0.304068            0.099880         1.000000
# State                     0.205069            0.032650         0.086108
# Project size              0.024297           -0.009333         0.009447
# Project organization      0.375739            0.064871         0.502209
# BG                        0.386941           -0.055844         0.277785
# Project Health            0.033295            0.017746        -0.078813
# On-hold                   0.072061            0.088189        -0.108203
# Percent complete         -0.035967            0.037350        -0.069807
#
#                          State  Project size  Project organization        BG  \
# Project Type          0.205069      0.024297              0.375739  0.386941
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".4f")
plt.title("Heatmap de Correlaciones", fontsize=14)
plt.show()

# %%
corr = Tabla_final_num.corr()

# Convertimos la matriz a formato "long" (pares de variables)
pairs_df = corr.unstack().reset_index()
pairs_df.columns = ["Variable_1", "Variable_2", "Correlación"]

# Quitamos los pares repetidos y la diagonal (una variable consigo misma)
pairs_df = pairs_df[pairs_df["Variable_1"] < pairs_df["Variable_2"]]

# Agregamos columna con valor absoluto
pairs_df["Correlación_abs"] = pairs_df["Correlación"].abs()

# Ordenamos por correlación absoluta y tomamos los 5 más altos
top5 = pairs_df.sort_values("Correlación_abs", ascending=False).head(5)

top5
# Out:
#          Variable_1            Variable_2  Correlación  Correlación_abs
# 25  Project manager  Project organization     0.502209         0.502209
# 73   Project Health                 State     0.493797         0.493797
# 60               BG          Project Type     0.386941         0.386941
# 5      Project Type  Project organization     0.375739         0.375739
# 65               BG  Project organization     0.369726         0.369726

# %%
Vars_Indep= Tabla_final_num[['BG', 'Project organization','Project manager']]
Var_Dep= Tabla_final_num['Project Type']

# %%
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['BG', 'Project organization', 'Project manager'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.27105459, 0.05769685, 0.00685964]),
#  'rank_': 3,
#  'singular_': array([555.90992536, 100.60729089,  29.29223822]),
#  'intercept_': np.float64(1.1713461501148648)}

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.22314538787245564

# %%
y_pred= model.predict(X=Tabla_final_num[['BG', 'Project organization','Project manager']])

# %%
Tabla_final_num.insert(0, 'Predicciones', y_pred)

# %%
sns.scatterplot(x='BG', y='Project Type', color="blue", data=Tabla_final_num)
sns.scatterplot(x='BG', y='Predicciones', color="red", data=Tabla_final_num)
# Out:
# <Axes: xlabel='BG', ylabel='Project Type'>

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.22314538787245564

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.47238267101202563)

# %%
Vars_Indep= Tabla_final_num[['Project manager', 'On-hold','Project organization']]
Var_Dep= Tabla_final_num['Geographical scope']

# %%
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Project manager', 'On-hold', 'Project organization'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.11327427, 8.84107271, 0.0317834 ]),
#  'rank_': 3,
#  'singular_': array([555.83702644, 100.23487121,   6.47508541]),
#  'intercept_': np.float64(25.479471333285247)}

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.019922365534011388

# %%
y_pred= model.predict(X=Tabla_final_num[['Project manager', 'On-hold','Project organization']])

# %%
Tabla_final_num.insert(0, 'Predicciones1', y_pred)

# %%
sns.scatterplot(x='Project manager', y='Geographical scope', color="blue", data=Tabla_final_num)
sns.scatterplot(x='Project manager', y='Predicciones1', color="red", data=Tabla_final_num)
# Out:
# <Axes: xlabel='Project manager', ylabel='Geographical scope'>

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.019922365534011388

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.14114661006914545)

# %%
Vars_Indep= Tabla_final_num[['Project organization', 'Project Type','BG']]
Var_Dep= Tabla_final_num['Project manager']

# %%
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Project organization', 'Project Type', 'BG'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([2.04946982, 1.98270896, 1.28811641]),
#  'rank_': 3,
#  'singular_': array([117.87095657,  32.98493642,  24.78477809]),
#  'intercept_': np.float64(13.899648371605181)}

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.27207717373629325

# %%
y_pred= model.predict(X=Tabla_final_num[['Project organization', 'Project Type','BG']])

# %%
Tabla_final_num.insert(0, 'Predicciones2', y_pred)

# %%
sns.scatterplot(x='Project organization', y='Project manager', color="blue", data=Tabla_final_num)
sns.scatterplot(x='Project organization', y='Predicciones2', color="red", data=Tabla_final_num)
# Out:
# <Axes: xlabel='Project organization', ylabel='Project manager'>

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.27207717373629325

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.5216101741111778)

# %%
Vars_Indep= Tabla_final_num[['Project Health', 'On-hold','Percent complete']]
Var_Dep= Tabla_final_num['State']

# %%
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Project Health', 'On-hold', 'Percent complete'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([ 0.22040397,  0.1312717 , -0.00141988]),
#  'rank_': 3,
#  'singular_': array([552.81144005,   9.29896794,   5.88072302]),
#  'intercept_': np.float64(0.6764565021552359)}

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.2976747501338206

# %%
y_pred= model.predict(X=Tabla_final_num[['Project Health', 'On-hold','Percent complete']])

# %%
Tabla_final_num.insert(0, 'Predicciones3', y_pred)

# %%
sns.scatterplot(x='Project Health', y='State', color="blue", data=Tabla_final_num)
sns.scatterplot(x='Project Health', y='Predicciones3', color="red", data=Tabla_final_num)
# Out:
# <Axes: xlabel='Project Health', ylabel='State'>

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.2976747501338206

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.5455957753995357)

# %%
Vars_Indep= Tabla_final_num[['On-hold', 'State','Project organization']]
Var_Dep= Tabla_final_num['Project size']

# %%
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['On-hold', 'State', 'Project organization'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.2122919 , 0.18632868, 0.01105358]),
#  'rank_': 3,
#  'singular_': array([116.58325046,   6.86929603,   4.33645321]),
#  'intercept_': np.float64(1.3049097910564367)}

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.03609338478400592

# %%
y_pred= model.predict(X=Tabla_final_num[['On-hold', 'State','Project organization']])

# %%
Tabla_final_num.insert(0, 'Predicciones4', y_pred)

# %%
sns.scatterplot(x='On-hold', y='Project size', color="blue", data=Tabla_final_num)
sns.scatterplot(x='On-hold', y='Predicciones4', color="red", data=Tabla_final_num)
# Out:
# <Axes: xlabel='On-hold', ylabel='Project size'>

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.03609338478400592

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.18998259073927254)

# %%
Vars_Indep= Tabla_final_num[['Project manager', 'Project Type','BG']]
Var_Dep= Tabla_final_num['Project organization']

# %%
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Project manager', 'Project Type', 'BG'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.08311945, 0.67634947, 0.6939358 ]),
#  'rank_': 3,
#  'singular_': array([552.79333765,  34.93886824,  24.77452219]),
#  'intercept_': np.float64(0.00483133997254015)}

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.33658664640325353

# %%
y_pred= model.predict(X=Tabla_final_num[['Project manager', 'Project Type','BG']])

# %%
Tabla_final_num.insert(0, 'Predicciones5', y_pred)

# %%
sns.scatterplot(x='Project manager', y='Project organization', color="blue", data=Tabla_final_num)
sns.scatterplot(x='Project manager', y='Predicciones5', color="red", data=Tabla_final_num)
# Out:
# <Axes: xlabel='Project manager', ylabel='Project organization'>

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.33658664640325353

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.5801608797594453)

# %%
Vars_Indep= Tabla_final_num[['Project Type', 'Project organization','State']]
Var_Dep= Tabla_final_num['BG']

# %%
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Project Type', 'Project organization', 'State'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.25835957, 0.06472533, 1.36138883]),
#  'rank_': 3,
#  'singular_': array([117.22029589,  29.01021706,   4.74647776]),
#  'intercept_': np.float64(0.3574246087328925)}

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.24949051562844393

# %%
y_pred= model.predict(X=Tabla_final_num[['Project Type', 'Project organization','State']])

# %%
Tabla_final_num.insert(0, 'Predicciones6', y_pred)

# %%
sns.scatterplot(x='Project Type', y='BG', color="blue", data=Tabla_final_num)
sns.scatterplot(x='Project Type', y='Predicciones6', color="red", data=Tabla_final_num)
# Out:
# <Axes: xlabel='Project Type', ylabel='BG'>

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.24949051562844393

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.4994902557892836)

# %%
Vars_Indep= Tabla_final_num[['State', 'On-hold','Percent complete']]
Var_Dep= Tabla_final_num['Project Health']

# %%
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['State', 'On-hold', 'Percent complete'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([ 0.76615126,  0.26661874, -0.00097445]),
#  'rank_': 3,
#  'singular_': array([552.81043034,   6.83078638,   4.29386133]),
#  'intercept_': np.float64(0.20920389505829018)}

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.2809978248989973

# %%
y_pred= model.predict(X=Tabla_final_num[['State', 'On-hold','Percent complete']])

# %%
Tabla_final_num.insert(0, 'Predicciones7', y_pred)

# %%
sns.scatterplot(x='State', y='Project Health', color="blue", data=Tabla_final_num)
sns.scatterplot(x='State', y='Predicciones7', color="red", data=Tabla_final_num)
# Out:
# <Axes: xlabel='State', ylabel='Project Health'>

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.2809978248989973

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.5300922796070485)

# %%
Vars_Indep= Tabla_final_num[['Project Health', 'State','BG']]
Var_Dep= Tabla_final_num['On-hold']

# %%
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Project Health', 'State', 'BG'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.17538111, 0.21412062, 0.03190642]),
#  'rank_': 3,
#  'singular_': array([31.90753968,  9.29372468,  3.90109218]),
#  'intercept_': np.float64(0.6585436741640964)}

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.16739122407072038

# %%
y_pred= model.predict(X=Tabla_final_num[['Project Health', 'State','BG']])

# %%
Tabla_final_num.insert(0, 'Predicciones8', y_pred)

# %%
sns.scatterplot(x='Project Health', y='On-hold', color="blue", data=Tabla_final_num)
sns.scatterplot(x='Project Health', y='Predicciones8', color="red", data=Tabla_final_num)
# Out:
# <Axes: xlabel='Project Health', ylabel='On-hold'>

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.16739122407072038

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.4091347260630908)

# %%
Vars_Indep= Tabla_final_num[['State', 'Project Health','Project organization']]
Var_Dep= Tabla_final_num['Percent complete']

# %%
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['State', 'Project Health', 'Project organization'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([-22.99009084,  -4.50780311,  -0.21969487]),
#  'rank_': 3,
#  'singular_': array([116.58662861,   9.31927734,   4.0305935 ]),
#  'intercept_': np.float64(71.2835666811569)}

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.06747737820713351

# %%
y_pred= model.predict(X=Tabla_final_num[['State', 'Project Health','Project organization']])

# %%
Tabla_final_num.insert(0, 'Predicciones9', y_pred)

# %%
sns.scatterplot(x='State', y='Percent complete', color="blue", data=Tabla_final_num)
sns.scatterplot(x='State', y='Predicciones9', color="red", data=Tabla_final_num)
# Out:
# <Axes: xlabel='State', ylabel='Percent complete'>

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.06747737820713351

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.2597640818264402)
